# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
cid = '0b07b283a2f943aa9ca99762b080e4bf'
secret = 'CLIENT_SECRET'
uri = 'http://localhost:8080/callback'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Get an artist using artist ID or uri - returns a dict with all artist info
artist = sp.artist('2WX2uTcsvV5OnS0inACecP')
# Access indiv artist data using dict indexing
artist_genres = artist['genres']
print(artist_genres)
# Out:
# ['indie cafe pop', 'pop', 'pop rock', 'post-teen pop']

# %%
#Reference: https://github.com/plamere/spotipy/blob/master/examples/my_top_artists.py
scope = "user-library-read user-read-recently-played user-top-read"
ranges = ['short_term', 'medium_term', 'long_term']

# Access indiv spotify account (prompts sign in on localhost uri)
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, client_id=cid, client_secret=secret, redirect_uri=uri))

# Get top artists
for sp_range in ['short_term', 'medium_term', 'long_term']:
    print("range:", sp_range)

    results = sp.current_user_top_artists(time_range=sp_range, limit=50)
#     print(results)

    for i, item in enumerate(results['items']):
        print(i, item['name'], "\t", item['genres'])
    print()
# Out:
# range: short_term
# 0 Lizzy McAlpine 	 ['alt z', 'boston folk', 'indie cafe pop', 'indie pop']
# 1 Taylor Swift 	 ['pop', 'post-teen pop']
# 2 dodie 	 ['alt z', 'indie pop', 'pop']
# 3 Lawrence 	 ['nyc pop', 'retro soul']
# 4 Lake Street Dive 	 ['boston rock', 'indie folk', 'new americana', 'stomp and holler']
# 5 John Denver 	 ['adult standards', 'classic country pop', 'folk', 'folk rock', 'mellow gold', 'soft rock']
# 6 Katrina Lenk 	 ['broadway']
# 7 The Beatles 	 ['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# 8 Jeremy Jordan 	 ['broadway', 'hollywood', 'show tunes']
# 9 The Band's Visit Original Broadway Band 	 ['broadway']
# 10 Sammy Rae & The Friends 	 ['indie pop', 'nyc pop']
# 11 Mandy Moore 	 ['dance pop', 'europop', 'hollywood', 'movie tunes', 'pop', 'post-teen pop']
# 12 Ben Fankhauser 	 ['broadway', 'hollywood', 'show tunes']
# 13 Olivia Rodrigo 	 ['pop', 'post-teen pop']
# 14 Sara Bareilles 	 ['acoustic pop', 'dance pop', 'lilith', 'neo mellow', 'pop', 'pop rock', 'post-teen pop']
# 15 Kacey Musgraves 	 ['contemporary country', 'country dawn', 'pop', 'post-teen pop', 'texas country']
# 16 Lin-Manuel Miranda 	 ['hollywood', 'show tunes']
# 17 Mandy Gonzalez 	 ['broadway', 'hollywood', 'show tunes']
# 18 'In The Heights' Original Broadway Company 	 ['broadway', 'show tunes']
# 19 One Direction 	 ['boy band', 'pop', 'post-teen pop', 'talent show']
#
# range: medium_term
# 0 Taylor Swift 	 ['pop', 'post-teen pop']
# 1 Lizzy McAlpine 	 ['alt z', 'boston folk', 'indie cafe pop', 'indie pop']
# 2 The Beatles 	 ['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# 3 dodie 	 ['alt z', 'indie pop', 'pop']
# 4 Hozier 	 ['irish singer-songwriter', 'modern rock', 'pop']
# 5 Justin Hurwitz 	 ['hollywood', 'movie tunes']
# 6 Pentatonix 	 ['a cappella']
# 7 Lawrence 	 ['nyc pop', 'retro soul']
# 8 John Denver 	 ['adult standards', 'classic country pop', 'folk', 'folk rock', 'mellow gold', 'soft rock']
# 9 Sara Bareilles 	 ['acoustic pop', 'dance pop', 'lilith', 'neo mellow', 'pop', 'pop rock', 'post-teen pop']
# 10 John Williams 	 ['soundtrack']
# 11 Lake Street Dive 	 ['boston rock', 'indie folk', 'new americana', 'stomp and holler']
# 12 Louie Zong 	 ['otacore', 'weirdcore']
# 13 Us The Duo 	 ['folk-pop', 'indiecoustica', 'neo mellow', 'viral pop']
# 14 Christy Altomare 	 ['broadway', 'hollywood', 'show tunes']
# 15 Ariana Grande 	 ['dance pop', 'pop', 'post-teen pop']
# 16 Jeremy Jordan 	 ['broadway', 'hollywood', 'show tunes']
# 17 Sammy Rae & The Friends 	 ['indie pop', 'nyc pop']
# 18 Jonathan Groff 	 ['hollywood', 'show tunes']
# 19 Kacey Musgraves 	 ['contemporary country', 'country dawn', 'pop', 'post-teen pop', 'texas country']
# 20 Laura Osnes 	 ['broadway', 'show tunes']
# 21 Katrina Lenk 	 ['broadway']
# 22 Anna Kendrick 	 ['hollywood', 'show tunes']
# 23 Jessie Shelton 	 []
# 24 James Taylor 	 ['adult standards', 'classic rock', 'folk', 'folk rock', 'mellow gold', 'rock', 'roots rock', 'singer-songwriter', 'soft rock']
# 25 Michael Bublé 	 ['adult standards', 'canadian pop', 'jazz pop', 'lounge']
# 26 Ben Platt 	 ['hollywood', 'pop', 'post-teen pop', 'show tunes']
# 27 Olivia Rodrigo 	 ['pop', 'post-teen pop']
# 28 Annaleigh Ashford 	 ['broadway', 'hollywood', 'show tunes']
# 29 Daniel Caesar 	 ['canadian contemporary r&b', 'pop', 'r&b']
# 30 Tori Kelly 	 ['dance pop', 'pop', 'post-teen pop', 'r&b', 'viral pop']
# 31 Abigail Barlow 	 ['alt z', 'modern indie pop']
# 32 The Band's Visit Original Broadway Band 	 ['broadway']
# 33 Jessie Mueller 	 ['broadway', 'hollywood', 'show tunes']
# 34 Yasunori Nishiki 	 ['japanese vgm', 'video game music']
# 35 Sir Simon Rattle 	 ['classical performance', 'orchestral performance']
# 36 Carrie Underwood 	 ['contemporary country', 'country', 'country dawn', 'country road', 'oklahoma country', 'post-teen pop']
# 37 Alan Menken 	 ['broadway', 'disney', 'hollywood', 'movie tunes', 'show tunes', 'soundtrack']
# 38 Vulfpeck 	 ['ann arbor indie', 'funk rock', 'instrumental funk']
# 39 Christian Borle 	 ['broadway', 'hollywood', 'show tunes']
# 40 Billie Eilish 	 ['electropop', 'pop']
# 41 Frank Sinatra 	 ['adult standards', 'easy listening', 'lounge']
# 42 The Chicks 	 ['country', 'country dawn']
# 43 Mandy Moore 	 ['dance pop', 'europop', 'hollywood', 'movie tunes', 'pop', 'post-teen pop']
# 44 Laura Bell Bundy 	 ['broadway', 'country dawn', 'hollywood', 'show tunes']
# 45 Derek Klena 	 ['broadway', 'hollywood', 'show tunes']
# 46 Zac Brown Band 	 ['contemporary country', 'country', 'country road', 'modern country rock']
# 47 John Bolton 	 ['broadway', 'hollywood', 'show tunes']
# 48 Reeve Carney 	 ['broadway', 'hollywood', 'show tunes']
# 49 André De Shields 	 ['broadway', 'hollywood', 'show tunes']
#
# range: long_term
# 0 Taylor Swift 	 ['pop', 'post-teen pop']
# 1 Ariana Grande 	 ['dance pop', 'pop', 'post-teen pop']
# 2 Louie Zong 	 ['otacore', 'weirdcore']
# 3 Hozier 	 ['irish singer-songwriter', 'modern rock', 'pop']
# 4 Jon Bellion 	 ['pop rap']
# 5 dodie 	 ['alt z', 'indie pop', 'pop']
# 6 Sara Bareilles 	 ['acoustic pop', 'dance pop', 'lilith', 'neo mellow', 'pop', 'pop rock', 'post-teen pop']
# 7 Lawrence 	 ['nyc pop', 'retro soul']
# 8 Lizzy McAlpine 	 ['alt z', 'boston folk', 'indie cafe pop', 'indie pop']
# 9 Billie Eilish 	 ['electropop', 'pop']
# 10 ABBA 	 ['europop', 'swedish pop']
# 11 Kacey Musgraves 	 ['contemporary country', 'country dawn', 'pop', 'post-teen pop', 'texas country']
# 12 Lake Street Dive 	 ['boston rock', 'indie folk', 'new americana', 'stomp and holler']
# 13 Harry Styles 	 ['pop', 'post-teen pop']
# 14 Tori Kelly 	 ['dance pop', 'pop', 'post-teen pop', 'r&b', 'viral pop']
# 15 The Beatles 	 ['beatlesque', 'british invasion', 'classic rock', 'merseybeat', 'psychedelic rock', 'rock']
# 16 Lady Gaga 	 ['dance pop', 'pop', 'post-teen pop']
# 17 Pentatonix 	 ['a cappella']
# 18 Ben Platt 	 ['hollywood', 'pop', 'post-teen pop', 'show tunes']
# 19 Daniel Caesar 	 ['canadian contemporary r&b', 'pop', 'r&b']
# 20 Laura Osnes 	 ['broadway', 'show tunes']
# 21 Shawn Mendes 	 ['canadian pop', 'dance pop', 'pop', 'post-teen pop', 'viral pop']
# 22 Original Broadway Cast Recording 	 ['broadway']
# 23 Ed Sheeran 	 ['pop', 'uk pop']
# 24 Michael Bublé 	 ['adult standards', 'canadian pop', 'jazz pop', 'lounge']
# 25 Panic! At The Disco 	 ['baroque pop', 'emo', 'modern rock']
# 26 Us The Duo 	 ['folk-pop', 'indiecoustica', 'neo mellow', 'viral pop']
# 27 Jeremy Jordan 	 ['broadway', 'hollywood', 'show tunes']
# 28 John Denver 	 ['adult standards', 'classic country pop', 'folk', 'folk rock', 'mellow gold', 'soft rock']
# 29 Jonas Brothers 	 ['boy band', 'dance pop', 'pop', 'pop rock', 'post-teen pop']
# 30 Sammy Rae & The Friends 	 ['indie pop', 'nyc pop']
# 31 Lin-Manuel Miranda 	 ['hollywood', 'show tunes']
# 32 Vulfpeck 	 ['ann arbor indie', 'funk rock', 'instrumental funk']
# 33 Crazy Ex-Girlfriend Cast 	 ['hollywood']
# 34 Katrina Lenk 	 ['broadway']
# 35 Rex Orange County 	 ['bedroom pop', 'pop']
# 36 Lizzo 	 ['dance pop', 'escape room', 'minnesota hip hop', 'pop', 'pop rap', 'post-teen pop', 'trap queen']
# 37 Queen 	 ['classic rock', 'glam rock', 'rock']
# 38 Troye Sivan 	 ['australian pop', 'dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop']
# 39 H.E.R. 	 ['alternative r&b', 'dance pop', 'pop', 'r&b']
# 40 Frank Sinatra 	 ['adult standards', 'easy listening', 'lounge']
# 41 One Direction 	 ['boy band', 'pop', 'post-teen pop', 'talent show']
# 42 Adele 	 ['british soul', 'pop', 'pop soul', 'uk pop']
# 43 5 Seconds of Summer 	 ['boy band', 'dance pop', 'electropop', 'pop', 'post-teen pop']
# 44 Eva Noblezada 	 ['broadway', 'hollywood', 'show tunes']
# 45 André De Shields 	 ['broadway', 'hollywood', 'show tunes']
# 46 Jessie Mueller 	 ['broadway', 'hollywood', 'show tunes']
# 47 Justin Hurwitz 	 ['hollywood', 'movie tunes']
# 48 Ella Fitzgerald 	 ['adult standards', 'jazz blues', 'swing', 'vocal jazz']
# 49 Anna Kendrick 	 ['hollywood', 'show tunes']

# %%
# Get top tracks

for sp_range in ranges:
    print("range:", sp_range)
    results = sp.current_user_top_tracks(time_range=sp_range, limit=50)
    for i, item in enumerate(results['items']):
        print(i, item['name'], '//', item['artists'][0]['name'])
    print()
# Out:
# range: short_term
# 0 In Agreement // Lizzy McAlpine
# 1 Give Me A Minute // Lizzy McAlpine
# 2 Nothing / Sad N Stuff // Lizzy McAlpine
# 3 ...What Are We? // Lizzy McAlpine
# 4 I Don't Know You At All // Lizzy McAlpine
# 5 Let Light Be Light // Lizzy McAlpine
# 6 Angelina // Lizzy McAlpine
# 7 Stupid // Lizzy McAlpine
# 8 Over-the-Ocean Call (Andrew) // Lizzy McAlpine
# 9 When The World Stopped Moving // Lizzy McAlpine
# 10 Where Do I Go? // Lizzy McAlpine
# 11 To the Mountains // Lizzy McAlpine
# 12 Pancakes for Dinner // Lizzy McAlpine
# 13 I Knew // Lizzy McAlpine
# 14 In What World // Lizzy McAlpine
# 15 Means Something // Lizzy McAlpine
# 16 Apple Pie // Lizzy McAlpine
# 17 Same Boat // Lizzy McAlpine
# 18 You, Love (Interlude) // Lizzy McAlpine
# 19 Changes // Cam
# 20 How Do I Tell You? // Lizzy McAlpine
# 21 Headstones and Land Mines // Lizzy McAlpine
# 22 All I Want - From "High School Musical: The Musical: The Series" // Olivia Rodrigo
# 23 drivers license // Olivia Rodrigo
# 24 All I've Ever Known // Eva Noblezada
# 25 Hypotheticals // Lake Street Dive
# 26 Air So Sweet // dodie
# 27 I Hear a Symphony // Cody Fry
# 28 Common Sense // Joshua Bassett
# 29 Good Life // Sammy Rae & The Friends
# 30 ivy // Taylor Swift
# 31 Poetry by Dead Men // Sara Bareilles
# 32 Spring Snow // Vampire Weekend
# 33 Orpheus // Sara Bareilles
# 34 I Did Something Bad // Taylor Swift
# 35 Mine // Taylor Swift
# 36 Take Me Home, Country Roads // John Denver
# 37 Thank God I'm a Country Boy // John Denver
# 38 Jackie and Wilson // Hozier
# 39 Jackie Onassis // Sammy Rae & The Friends
# 40 Whiskey, Whiskey, Whiskey // John Mayer
# 41 When Will My Life Begin? - From "Tangled" / Soundtrack Version // Mandy Moore
# 42 Waiting // The Band's Visit Original Broadway Company
# 43 hoax // Taylor Swift
# 44 the lakes - bonus track // Taylor Swift
# 45 There Is Only One You // Us The Duo
# 46 Same Old News // Lake Street Dive
# 47 Pocket // Louie Zong
# 48 If This Was A Movie // Taylor Swift
# 49 Honor To Us All - From "Mulan"/Soundtrack // Lea Salonga
#
# range: medium_term
# 0 Pancakes for Dinner // Lizzy McAlpine
# 1 Give Me A Minute // Lizzy McAlpine
# 2 Nothing / Sad N Stuff // Lizzy McAlpine
# 3 ‘tis the damn season // Taylor Swift
# 4 To the Mountains // Lizzy McAlpine
# 5 ivy // Taylor Swift
# 6 Same Boat // Lizzy McAlpine
# 7 Over-the-Ocean Call (Andrew) // Lizzy McAlpine
# 8 Mia & Sebastian’s Theme // Justin Hurwitz
# 9 drivers license // Olivia Rodrigo
# 10 I Hear a Symphony // Cody Fry
# 11 Apple Pie // Lizzy McAlpine
# 12 Common Sense // Joshua Bassett
# 13 I Knew // Lizzy McAlpine
# 14 Where Do I Go? // Lizzy McAlpine
# 15 no body, no crime (feat. HAIM) // Taylor Swift
# 16 Orpheus // Sara Bareilles
# 17 How Do I Tell You? // Lizzy McAlpine
# 18 willow // Taylor Swift
# 19 Binary Sunset // The Crimson Big Movie Orchestra
# 20 Means Something // Lizzy McAlpine
# 21 the lakes - bonus track // Taylor Swift
# 22 In Agreement // Lizzy McAlpine
# 23 Grow As We Go // Ben Platt
# 24 You, Love (Interlude) // Lizzy McAlpine
# 25 Heartbreak Hotel // Abigail Barlow
# 26 Whiskey, Whiskey, Whiskey // John Mayer
# 27 Variations on a Rococo Theme, Op. 33 for cello and orchestra: Var. VI: Andante // Pyotr Ilyich Tchaikovsky
# 28 The Golden Hour // Louie Zong
# 29 Swan Lake, Op.20 Suite: 1. Scene - Swan Theme // Pyotr Ilyich Tchaikovsky
# 30 All I've Ever Known // Eva Noblezada
# 31 The Impossible Girl (Clara's Theme) // Dominik Hauser
# 32 Poetry by Dead Men // Sara Bareilles
# 33 Lily's Theme // Alexandre Desplat
# 34 All I Want - From "High School Musical: The Musical: The Series" // Olivia Rodrigo
# 35 Headstones and Land Mines // Lizzy McAlpine
# 36 Epilogue // Justin Hurwitz
# 37 Grilled Cheese // Peach Face
# 38 tolerate it // Taylor Swift
# 39 Gymnopédie No. 1 // Erik Satie
# 40 Planetarium // Justin Hurwitz
# 41 Goodbye Yellow Brick Road - Remastered 2014 // Elton John
# 42 Jolene // Zac Brown Band
# 43 champagne problems // Taylor Swift
# 44 Mr. Perfectly Fine (Taylor’s Version) (From The Vault) // Taylor Swift
# 45 Flowers in My Hair // Wes Reeve
# 46 Teardrops On My Guitar - Radio Single Remix // Taylor Swift
# 47 I'm Only Me (When I'm Not Sober) // Abigail Barlow
# 48 You // dodie
# 49 long story short // Taylor Swift
#
# range: long_term
# 0 Soul’s Anthem (It Is Well) // Tori Kelly
# 1 Pancakes for Dinner // Lizzy McAlpine
# 2 Not What I Meant (feat. Lewis Watson) // dodie
# 3 Burned Out // dodie
# 4 Whiskey, Whiskey, Whiskey // John Mayer
# 5 raindrops (an angel cried) // Ariana Grande
# 6 Breathe // 'In The Heights' Original Broadway Company
# 7 Grow As We Go // Ben Platt
# 8 Give Me A Minute // Lizzy McAlpine
# 9 Sour Candy // Melt
# 10 when the party's over // Billie Eilish
# 11 The Golden Hour // Louie Zong
# 12 Evergreen // Yebba
# 13 the lakes - bonus track // Taylor Swift
# 14 Almost (Sweet Music) // Hozier
# 15 Pageant Material // Kacey Musgraves
# 16 Older // Ben Platt
# 17 Something Different // Katrina Lenk
# 18 Loving Is Easy // Rex Orange County
# 19 needy // Ariana Grande
# 20 idontwannabeyouanymore // Billie Eilish
# 21 Jackie and Wilson // Hozier
# 22 Always Remember Us This Way // Lady Gaga
# 23 Best Part of Me (feat. YEBBA) // Ed Sheeran
# 24 JT // Jon Bellion
# 25 Love Of My Life - Remastered 2011 // Queen
# 26 SUPERPOSITION // Daniel Caesar
# 27 Nothing / Sad N Stuff // Lizzy McAlpine
# 28 Wait for the Moment // Vulfpeck
# 29 pete davidson // Ariana Grande
# 30 Thumbnail // Louie Zong
# 31 Omar Sharif // Katrina Lenk
# 32 Why Did It Have To Be Me? // Josh Dylan
# 33 Guiltless // dodie
# 34 Follow Your Arrow // Kacey Musgraves
# 35 thank u, next // Ariana Grande
# 36 No Me Diga // Andrea Burns
# 37 Monster // dodie
# 38 Ivy // Frank Ocean
# 39 ‘tis the damn season // Taylor Swift
# 40 in my head // Ariana Grande
# 41 Andante, Andante // Lily James
# 42 Help Us To Love // Tori Kelly
# 43 In My Dreams // Christy Altomare
# 44 Japanese Denim // Daniel Caesar
# 45 Welcome to Nowhere // Katrina Lenk
# 46 Andante, Andante // ABBA
# 47 Pure Imagination // SoCal VoCals
# 48 Like Real People Do // Hozier
# 49 Orpheus // Sara Bareilles
